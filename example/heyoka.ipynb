# %%
import sys
sys.path.append("../data_util")

import numpy as np
import matplotlib.pyplot as plt

from heyoka_integrators import build_taylor_cr3bp

# %%
ta, _, _ = build_taylor_cr3bp(mu = 1.215058560962404e-02)

# %%
ta.state[:] = [1.1540242813087864,
        -2.4170502654082446e-28,
        -0.1384196144071876,
        4.06530060663289e-15,
        -0.21493019200956867,
        8.48098638414804e-15]

# %%
out = ta.propagate_grid(grid = np.linspace(0, 800*0.015, 800))

# %%
data = out[4]

# %%
plt.plot(np.linspace(0, 800*0.015, 800), data[:,0])

# %%
ta.time = 0

# %%
ta
# Out:
# Tolerance               : 2.220446049250313e-16
# High accuracy           : false
# Compact mode            : false
# Taylor order            : 20
# Dimension               : 6
# Time                    : 0
# State                   : [1.0907481577234583, 0.1297896346379538, -0.046741873494888384, 0.08343097262678797, -0.009299422507268723, -0.19481094140046484]
# Parameters              : [0.01215058560962404]

# %%
ta.state
# Out:
# array([ 1.09074816,  0.12978963, -0.04674187,  0.08343097, -0.00929942,
#        -0.19481094])
